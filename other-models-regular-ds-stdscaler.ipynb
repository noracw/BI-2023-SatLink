# %%
# !pip install xgboost

# %%
import pickle
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, r2_score
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor, VotingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.inspection import permutation_importance

from keras import Model, Sequential
from keras.layers import Dense, Dropout
from keras.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

import joblib
import xgboost as xgb
print("XGB Version:", xgb.__version__)
# Out:
# XGB Version: 2.0.0

# %%
# carregar os dados de entrada
inputs_file = 'input_db_29_08_2023_14_26_20.pkl'
with open(inputs_file, 'rb') as handle_inputs:
    inputs = pickle.load(handle_inputs)

# %%
inputs.head()
# Out:
#     site_lat  site_long   sat_long       freq       eirp   hsat  bw_total  \
# 0 -16.284610 -53.833962 -16.791579  15.777944  55.604089  35786        36
# 1 -19.589594 -47.124346 -25.670642   8.138563  68.860880  35786        36
# 2 -19.167619 -34.986496  -2.622435   5.349325  56.252903  35786        36
# 3  -7.438339 -65.779685 -40.611067  13.980570  79.680713  35786        36
# 4 -31.421909 -51.281737 -86.449047  15.837202  66.010417  35786        36
#
#      bw_util  rolloff     mod      fec  snr_threshold  ant_size   ant_eff  \
# 0  16.155547      0.2  32APSK  126/180      12.731030  1.053027  0.721533
# 1  22.226415      0.2  32APSK  135/180      13.567632  4.362265  0.351699
# 2  35.827805      0.2  64APSK  162/180      19.590329  1.207189  0.530488
# 3  14.203504      0.2    8PSK  100/180       5.407456  1.065575  0.366528
# 4   9.488156      0.2  32APSK  126/180      12.731030  2.561817  0.116897
#
#     lnb_gain  lnb_noise_temp  cable_loss  ant_max_depoint
# 0  60.752933       25.492447    5.587639         0.517839
# 1  58.632002       13.328408    5.246875         1.412518
# 2  57.036432       28.600282    5.894995         1.506105
# 3  62.943757       30.125849    4.965485         1.081404
# 4  56.777167       21.047025    4.254455         0.368052

# %%
inputs = inputs.drop(columns=["hsat", "bw_total", "mod", "fec", "rolloff"])

# %%
# carregar os dados de saída -
# apenas a coluna availability é relevante para o problema,
# pode-se ignorar as demais para o treinamento e teste
results_file = 'results_db_29_08_2023_14_26_20.pkl'
with open(results_file, 'rb') as handle_results:
    results = pickle.load(handle_results)

# %%
results.head()
# Out:
#    availability        a_fs       a_g       a_c        a_r       a_s  \
# 0        99.904  207.841452  0.322924  0.966845   9.079432  0.526741
# 1        99.999  201.903879  0.065287  0.201974   7.102761  0.439884
# 2        96.460  198.393586  0.065097  0.039061   0.016178  0.116006
# 3        99.999  206.567603  0.201870  0.712902  27.381892  0.930295
# 4        99.990  207.986262  0.381950  1.032110  16.817812  0.716087
#
#          a_t       a_tot  a_depoint          c_n0  ...  earth_radius  \
# 0  10.383000  220.241483   2.017030     84.759447  ...   6367.489544
# 1   7.383255  277.812514  68.525380    112.688241  ...   6367.489544
# 2   0.193583  201.164695   2.577525 -99916.332614  ...   6367.489544
# 3  28.312062  241.951596   7.071931     86.145051  ...   6367.489544
# 4  18.246230  232.308445   6.075953     82.544269  ...   6367.489544
#
#    elevation_angle      distance      fig_merit  noise_ground  noise_sky  \
# 0        43.741256  37499.215397      24.276649          10.0  10.860506
# 1        56.474767  36698.322584      95.134206          10.0   3.208548
# 2        47.007765  37271.796260 -100000.000000          10.0   3.867110
# 3        59.412644  36547.299501      23.855004          10.0   5.183472
# 4        37.330831  37986.968867      26.033504          10.0  12.583786
#
#     ant_noise  noise_total   ant_gain   ant_3db
# 0  260.815713   286.308799  43.398944  1.263074
# 1  235.351027   248.680367  46.873483  0.591097
# 2   25.687222    54.289160  33.854824  3.249709
# 3  284.602019   314.728183  39.509835  1.408672
# 4  281.070225   302.118263  43.249134  0.517240
#
# [5 rows x 21 columns]

# %%
# preprocessamento da base de dados -
# as linhas cuja coluna fig_merit têm valor igual a -100000
# são casos inválidos e devem ser removidos
filter_matrix = results.fig_merit != -100000
print(filter_matrix.head())
print(np.sum(filter_matrix))
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: fig_merit, dtype: bool
# 1457619

# %%
filtered_inputs = inputs[filter_matrix]
filtered_results = results[filter_matrix]

# %%
print(filtered_inputs.describe())
for column in inputs.columns:
    # Creating plot
    plt.hist(filtered_inputs[column])
    plt.show()
    plt.boxplot(filtered_inputs[column])
    plt.show()
# Out:
#            site_lat     site_long      sat_long          freq          eirp  \
# count  1.457619e+06  1.457619e+06  1.457619e+06  1.457619e+06  1.457619e+06
# mean  -1.505471e+01 -5.330440e+01 -5.230916e+01  1.132981e+01  5.091215e+01
# std    1.061157e+01  1.080609e+01  3.258509e+01  4.041949e+00  1.763086e+01
# min   -3.368997e+01 -7.288998e+01 -1.079999e+02  3.000049e+00  1.500033e+01
# 25%   -2.430390e+01 -6.240066e+01 -8.093161e+01  7.965716e+00  3.691857e+01
# 50%   -1.470179e+01 -5.317498e+01 -5.223987e+01  1.150008e+01  5.183633e+01
# 75%   -5.817384e+00 -4.398199e+01 -2.366515e+01  1.483480e+01  6.597661e+01
# max    2.819986e+00 -3.480004e+01  2.999920e+00  1.799999e+01  7.999994e+01
#
#             bw_util  snr_threshold      ant_size       ant_eff      lnb_gain  \
# count  1.457619e+06   1.457619e+06  1.457619e+06  1.457619e+06  1.457619e+06
# mean   1.850569e+01   8.798743e+00  2.383836e+00  5.565397e-01  5.999881e+01
# std    1.009771e+01   5.843946e+00  1.251949e+00  2.587691e-01  2.888258e+00
# min    1.000003e+00  -2.297824e+00  1.000031e-01  1.000027e-01  5.500000e+01
# 25%    9.766769e+00   3.744510e+00  1.320304e+00  3.340779e-01  5.749916e+01
# 50%    1.850554e+01   8.670497e+00  2.412612e+00  5.596365e-01  5.999717e+01
# 75%    2.724300e+01   1.382831e+01  3.468454e+00  7.806070e-01  6.249867e+01
# max    3.599999e+01   1.959033e+01  4.499999e+00  9.999994e-01  6.500000e+01
#
#        lnb_noise_temp    cable_loss  ant_max_depoint
# count    1.457619e+06  1.457619e+06     1.457619e+06
# mean     2.204086e+01  2.734260e+00     1.024896e+00
# std      5.771862e+00  1.692303e+00     5.631654e-01
# min      1.200001e+01  1.000104e-01     5.000065e-02
# 25%      1.704945e+01  1.249548e+00     5.366922e-01
# 50%      2.206128e+01  2.558779e+00     1.025000e+00
# 75%      2.704186e+01  4.146127e+00     1.512894e+00
# max      3.199995e+01  5.999996e+00     2.000000e+00

# %%
filtered_results["availability"].describe()
# Out:
# count    1.457619e+06
# mean     9.929238e+01
# std      1.374950e+00
# min      9.500000e+01
# 25%      9.964200e+01
# 50%      9.999200e+01
# 75%      9.999900e+01
# max      9.999900e+01
# Name: availability, dtype: float64

# %%
plt.boxplot(filtered_results["availability"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0
#         98.9367125, 98.94921  , 98.9617075, 98.974205 , 98.9867025,
#         98.9992   , 99.0116975, 99.024195 , 99.0366925, 99.04919  ,
#         99.0616875, 99.074185 , 99.0866825, 99.09918  , 99.1116775,
#         99.124175 , 99.1366725, 99.14917  , 99.1616675, 99.174165 ,
#         99.1866625, 99.19916  , 99.2116575, 99.224155 , 99.2366525,
#         99.24915  , 99.2616475, 99.274145 , 99.2866425, 99.29914  ,
#         99.3116375, 99.324135 , 99.3366325, 99.34913  , 99.3616275,
#         99.374125 , 99.3866225, 99.39912  , 99.4116175, 99.424115 ,
#         99.4366125, 99.44911  , 99.4616075, 99.474105 , 99.4866025,
#         99.4991   , 99.5115975, 99.524095 , 99.5365925, 99.54909  ,
#         99.5615875, 99.574085 , 99.5865825, 99.59908  , 99.6115775,
#         99.624075 , 99.6365725, 99.64907  , 99.6615675, 99.674065 ,
#         99.6865625, 99.69906  , 99.7115575, 99.724055 , 99.7365525,
#         99.74905  , 99.7615475, 99.774045 , 99.7865425, 99.79904  ,
#         99.8115375, 99.824035 , 99.8365325, 99.84903  , 99.8615275,
#         99.874025 , 99.8865225, 99.89902  , 99.9115175, 99.924015 ,
#         99.9365125, 99.94901  , 99.9615075, 99.974005 , 99.9865025,
#         99.999    ]),
#  <BarContainer object of 400 artists>)

# %%
df = filtered_inputs.assign(availability=filtered_results["availability"])
df.head()
# Out:
#     site_lat  site_long   sat_long       freq       eirp    bw_util  \
# 0 -16.284610 -53.833962 -16.791579  15.777944  55.604089  16.155547
# 1 -19.589594 -47.124346 -25.670642   8.138563  68.860880  22.226415
# 3  -7.438339 -65.779685 -40.611067  13.980570  79.680713  14.203504
# 4 -31.421909 -51.281737 -86.449047  15.837202  66.010417   9.488156
# 5 -17.303467 -41.668725 -66.343144  12.480028  27.720772  31.814645
#
#    snr_threshold  ant_size   ant_eff   lnb_gain  lnb_noise_temp  cable_loss  \
# 0      12.731030  1.053027  0.721533  60.752933       25.492447    5.587639
# 1      13.567632  4.362265  0.351699  58.632002       13.328408    5.246875
# 3       5.407456  1.065575  0.366528  62.943757       30.125849    4.965485
# 4      12.731030  2.561817  0.116897  56.777167       21.047025    4.254455
# 5       8.326742  4.452849  0.583401  64.208048       17.289375    2.862834
#
#    ant_max_depoint  availability
# 0         0.517839        99.904
# 1         1.412518        99.999
# 3         1.081404        99.999
# 4         0.368052        99.990
# 5         1.010339        99.554

# %%
sns.heatmap(df.corr())
plt.show()

# %%
# setando a semente para divisão dos conjuntos de treino e teste
np.random.seed(0)

# %%
# separando os dados em treino e teste
x_train, x_test, y_train, y_test = train_test_split(filtered_inputs, filtered_results['availability'], test_size=0.2)

# %%
# alguns dados estatisticos por atributo
x_train.describe()
# Out:
#            site_lat     site_long      sat_long          freq          eirp  \
# count  1.166095e+06  1.166095e+06  1.166095e+06  1.166095e+06  1.166095e+06
# mean  -1.505710e+01 -5.330025e+01 -5.232505e+01  1.132592e+01  5.091384e+01
# std    1.060994e+01  1.080551e+01  3.258371e+01  4.042234e+00  1.763703e+01
# min   -3.368997e+01 -7.288998e+01 -1.079999e+02  3.000049e+00  1.500033e+01
# 25%   -2.430311e+01 -6.239452e+01 -8.093318e+01  7.959209e+00  3.690922e+01
# 50%   -1.470912e+01 -5.317090e+01 -5.227094e+01  1.149744e+01  5.184141e+01
# 75%   -5.822522e+00 -4.397547e+01 -2.369243e+01  1.482901e+01  6.598846e+01
# max    2.819986e+00 -3.480004e+01  2.999885e+00  1.799997e+01  7.999990e+01
#
#             bw_util  snr_threshold      ant_size       ant_eff      lnb_gain  \
# count  1.166095e+06   1.166095e+06  1.166095e+06  1.166095e+06  1.166095e+06
# mean   1.849934e+01   8.801438e+00  2.383161e+00  5.564281e-01  5.999895e+01
# std    1.009759e+01   5.843931e+00  1.251836e+00  2.587791e-01  2.888473e+00
# min    1.000003e+00  -2.297824e+00  1.000031e-01  1.000027e-01  5.500000e+01
# 25%    9.765242e+00   3.744510e+00  1.319557e+00  3.340053e-01  5.750003e+01
# 50%    1.849531e+01   8.670497e+00  2.410881e+00  5.593250e-01  5.999796e+01
# 75%    2.723730e+01   1.382831e+01  3.467692e+00  7.805493e-01  6.249920e+01
# max    3.599999e+01   1.959033e+01  4.499999e+00  9.999982e-01  6.499999e+01
#
#        lnb_noise_temp    cable_loss  ant_max_depoint
# count    1.166095e+06  1.166095e+06     1.166095e+06
# mean     2.204306e+01  2.734617e+00     1.025127e+00
# std      5.773442e+00  1.692083e+00     5.633102e-01
# min      1.200001e+01  1.000104e-01     5.000065e-02
# 25%      1.704972e+01  1.250094e+00     5.364574e-01
# 50%      2.206712e+01  2.559478e+00     1.025672e+00
# 75%      2.704564e+01  4.145796e+00     1.513118e+00
# max      3.199995e+01  5.999996e+00     2.000000e+00

# %%
# normalização dos dados
preprocessParams = preprocessing.StandardScaler().fit(x_train)
x_train_normalized = preprocessParams.transform(x_train)
x_test_normalized = preprocessParams.transform(x_test)

# %%
y_train_num = pd.to_numeric(y_train)
y_train_df = pd.DataFrame(y_train_num)
y_test_num = pd.to_numeric(y_test)
y_test_df = pd.DataFrame(y_test_num)

preprocessParamsY = preprocessing.StandardScaler().fit(y_train_df)
y_train_normalized = preprocessParamsY.transform(y_train_df)
y_test_normalized = preprocessParamsY.transform(y_test_df)

# %%
plt.hist(y_train_normalized)
# Out:
# (array([ 14148.,  44693.,  61161.,  61943.,   5547.,   8086.,  11398.,
#          17057.,  43202., 898860.]),
#  array([-3.12126206, -2.75774621, -2.39423035, -2.0307145 , -1.66719865,
#         -1.30368279, -0.94016694, -0.57665109, -0.21313523,  0.15038062,
#          0.51389648]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y_test_normalized)
# Out:
# (array([  3473.,  10961.,  15361.,  15747.,   1389.,   2012.,   2779.,
#           4357.,  10659., 224786.]),
#  array([-3.12198938, -2.7584008 , -2.39481221, -2.03122363, -1.66763504,
#         -1.30404645, -0.94045787, -0.57686928, -0.2132807 ,  0.15030789,
#          0.51389648]),
#  <BarContainer object of 10 artists>)

# %%
x_train_normalized.shape[1:]
# Out:
# (13,)

# %%
feature_names = filtered_inputs.columns

# %%
# teste de outros modelos de IA
model1 = LinearRegression()
model1.fit(x_train_normalized, y_train_normalized)
# Out:
# LinearRegression()

# %%
model1.score(x_test_normalized, y_test_normalized)
# Out:
# 0.539319317471245

# %%
# Get the metrics on the validation data
predicted_availability1 = model1.predict(x_test_normalized)
mae1 = mean_absolute_error(y_test_normalized, predicted_availability1)
print('Linear test MAE = ', mae1)
# Out:
# Linear test MAE =  tf.Tensor([0.45187017 1.51780783 0.51786102 ... 0.71707511 0.48112186 0.65706794], shape=(291524,), dtype=float64)

# %%
mean_mae1 = tf.math.reduce_mean(mae1)
print('Linear test mean MSE = ', mean_mae1)
std_mae1 = tf.math.reduce_std(mae1)
print('Linear test std RMSE = ', std_mae1)
# Out:
# Linear test mean MSE =  tf.Tensor(0.5483308119150793, shape=(), dtype=float64)
# Linear test std RMSE =  tf.Tensor(0.4002005702604313, shape=(), dtype=float64)

# %%
mse1 = mean_squared_error(y_test_normalized, predicted_availability1)
rmse1 = mse1**.5
print('Linear test MSE = ', mse1)
print('Linear test RMSE = ', rmse1)
# Out:
# Linear test MSE =  tf.Tensor([0.20418665 2.30374062 0.26818003 ... 0.51419671 0.23147824 0.43173828], shape=(291524,), dtype=float64)
# Linear test RMSE =  tf.Tensor([0.45187017 1.51780783 0.51786102 ... 0.71707511 0.48112186 0.65706794], shape=(291524,), dtype=float64)

# %%
mean_mse1 = tf.math.reduce_mean(mse1)
print('Linear test mean MAE = ', mean_mse1)
mean_rmse1 = tf.math.reduce_mean(rmse1)
print('Linear test mean MAE = ', mean_rmse1)
# Out:
# Linear test mean MAE =  tf.Tensor(0.4608271757322244, shape=(), dtype=float64)
# Linear test mean MAE =  tf.Tensor(0.5483308119150793, shape=(), dtype=float64)

# %%
model2 = RandomForestRegressor()
model2.fit(x_train_normalized, y_train_normalized.T[0])
# Out:
# RandomForestRegressor()

# %%
# save model
joblib.dump(model2, "random_forest.joblib")
# Out:
# ['random_forest.joblib']

# %%
model2.score(x_test_normalized, y_test_normalized.T[0])
# Out:
# 0.909455881077818

# %%
# Get the metrics on the validation data
predicted_availability2 = model2.predict(x_test_normalized)

# %%
mae2 = mean_absolute_error(y_test_normalized.T[0], predicted_availability2)
print('Random forest test MAE = ', mae2)
# Out:
# Random forest test MAE =  tf.Tensor(0.12534544431411976, shape=(), dtype=float64)

# %%
mse2 = mean_squared_error(y_test_normalized.T[0], predicted_availability2)
rmse2 = mse2**.5
print('Random forest test MSE = ', mse2)
print('Random forest test RMSE = ', rmse2)
# Out:
# Random forest test MSE =  tf.Tensor(0.09057291131252793, shape=(), dtype=float64)
# Random forest test RMSE =  tf.Tensor(0.3009533374337755, shape=(), dtype=float64)

# %%
params = model2.get_params()
params
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# obtain feature importance
feature_importance2 = model2.feature_importances_

# sort features according to importance
sorted_idx = np.argsort(feature_importance2)
pos = np.arange(sorted_idx.shape[0])

# plot feature importances
plt.barh(pos, feature_importance2[sorted_idx], align="center")
plt.yticks(pos, np.array(feature_names)[sorted_idx])
plt.title("Feature Importance (MDI)")
plt.xlabel("Mean decrease in impurity");

# %%
result2 = permutation_importance(
    model2, x_test_normalized, y_test_normalized.T[0], n_repeats=10, random_state=42, n_jobs=2
) 

tree_importances2 = pd.Series(result2.importances_mean, index=feature_names)

# %%
# sort features according to importance
sorted_idx = np.argsort(tree_importances2)
pos = np.arange(sorted_idx.shape[0])

# plot feature importances
plt.barh(pos, tree_importances2[sorted_idx], align="center")
plt.yticks(pos, np.array(feature_names)[sorted_idx])
plt.title("Feature Importance (MDI)")
plt.xlabel("Mean decrease in impurity");

# %%
plt.boxplot(
    result2.importances[sorted_idx].T,
    vert=False,
    labels=np.array(feature_names)[sorted_idx],
)

plt.title("Permutation Importance (test set)")
# Out:
# Text(0.5, 1.0, 'Permutation Importance (test set)')

# %%
model3 = HistGradientBoostingRegressor()
model3.fit(x_train_normalized, y_train_normalized.T[0])
# Out:
# HistGradientBoostingRegressor()

# %%
# save model
joblib.dump(model3, "hist_grad_boost.joblib")
# Out:
# ['hist_grad_boost.joblib']

# %%
model3.score(x_test_normalized, y_test_normalized.T[0])
# Out:
# 0.8705462652360525

# %%
# Get the metrics on the validation data
predicted_availability3 = model3.predict(x_test_normalized)

# %%
mae3 = mean_absolute_error(y_test_normalized.T[0], predicted_availability3)
print('Hist. Grad. Boost. test MAE = ', mae3)
# Out:
# Hist. Grad. Boost. test MAE =  tf.Tensor(0.1900352449903753, shape=(), dtype=float64)

# %%
mse3 = mean_squared_error(y_test_normalized.T[0], predicted_availability3)
rmse3 = mse3**.5
print('Hist. Grad. Boost. test MSE = ', mse3)
print('Hist. Grad. Boost. test RMSE = ', rmse3)
# Out:
# Hist. Grad. Boost. test MSE =  tf.Tensor(0.12949490013733053, shape=(), dtype=float64)
# Hist. Grad. Boost. test RMSE =  tf.Tensor(0.35985399836229487, shape=(), dtype=float64)

# %%
params = model3.get_params()
params
# Out:
# {'categorical_features': None,
#  'early_stopping': 'auto',
#  'interaction_cst': None,
#  'l2_regularization': 0.0,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_bins': 255,
#  'max_depth': None,
#  'max_iter': 100,
#  'max_leaf_nodes': 31,
#  'min_samples_leaf': 20,
#  'monotonic_cst': None,
#  'n_iter_no_change': 10,
#  'quantile': None,
#  'random_state': None,
#  'scoring': 'loss',
#  'tol': 1e-07,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
test_score = np.zeros((params["max_iter"]+1,), dtype=np.float64)

for i, y_pred in enumerate(model3.staged_predict(x_test_normalized)):
    test_score[i] = mean_squared_error(y_test_normalized.T[0], y_pred)

fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title("Deviance")
plt.plot(
    np.arange(params["max_iter"]+1),
    model3.train_score_,
    "b-",
    label="Training Set Deviance",
)
plt.plot(
    np.arange(params["max_iter"]+1), test_score, "r-", label="Test Set Deviance"
)
plt.legend(loc="upper right")
plt.xlabel("Boosting Iterations")
plt.ylabel("Deviance")
plt.show()

# %%
result3 = permutation_importance(
    model3, x_test_normalized, y_test_normalized.T[0], n_repeats=10, random_state=42, n_jobs=2
)

tree_importances3 = pd.Series(result3.importances_mean, index=feature_names)

# %%
# sort features according to importance
sorted_idx = np.argsort(tree_importances3)
pos = np.arange(sorted_idx.shape[0])

# plot feature importances
plt.barh(pos, tree_importances3[sorted_idx], align="center")
plt.yticks(pos, np.array(feature_names)[sorted_idx])
plt.title("Feature Importance (MDI)")
plt.xlabel("Mean decrease in impurity");

# %%
plt.boxplot(
    result3.importances[sorted_idx].T,
    vert=False,
    labels=np.array(feature_names)[sorted_idx],
)

plt.title("Permutation Importance (test set)")
# Out:
# Text(0.5, 1.0, 'Permutation Importance (test set)')

# %%
eval_set = [(x_train_normalized, y_train_normalized), (x_test_normalized, y_test_normalized)]
model4 = xgb.XGBRegressor()
model4.fit(x_train_normalized,
           y_train_normalized,
           verbose=True,
           eval_set=eval_set)
# Out:
# [0]	validation_0-rmse:0.79918	validation_1-rmse:0.80006
# [1]	validation_0-rmse:0.66781	validation_1-rmse:0.66891
# [2]	validation_0-rmse:0.58344	validation_1-rmse:0.58508
# [3]	validation_0-rmse:0.52875	validation_1-rmse:0.53102
# [4]	validation_0-rmse:0.49370	validation_1-rmse:0.49618
# [5]	validation_0-rmse:0.46941	validation_1-rmse:0.47226
# [6]	validation_0-rmse:0.45412	validation_1-rmse:0.45711
# [7]	validation_0-rmse:0.44259	validation_1-rmse:0.44561
# [8]	validation_0-rmse:0.43251	validation_1-rmse:0.43554
# [9]	validation_0-rmse:0.42551	validation_1-rmse:0.42866
# [10]	validation_0-rmse:0.41817	validation_1-rmse:0.42136
# [11]	validation_0-rmse:0.41135	validation_1-rmse:0.41479
# [12]	validation_0-rmse:0.40751	validation_1-rmse:0.41111
# [13]	validation_0-rmse:0.40362	validation_1-rmse:0.40716
# [14]	validation_0-rmse:0.40043	validation_1-rmse:0.40411
# [15]	validation_0-rmse:0.39819	validation_1-rmse:0.40192
# [16]	validation_0-rmse:0.39406	validation_1-rmse:0.39779
# [17]	validation_0-rmse:0.39238	validation_1-rmse:0.39609
# [18]	validation_0-rmse:0.39037	validation_1-rmse:0.39413
# [19]	validation_0-rmse:0.38792	validation_1-rmse:0.39171
# [20]	validation_0-rmse:0.38668	validation_1-rmse:0.39052
# [21]	validation_0-rmse:0.38560	validation_1-rmse:0.38951
# [22]	validation_0-rmse:0.38344	validation_1-rmse:0.38744
# [23]	validation_0-rmse:0.38147	validation_1-rmse:0.38563
# [24]	validation_0-rmse:0.38067	validation_1-rmse:0.38491
# [25]	validation_0-rmse:0.37993	validation_1-rmse:0.38429
# [26]	validation_0-rmse:0.37882	validation_1-rmse:0.38329
# [27]	validation_0-rmse:0.37813	validation_1-rmse:0.38272
# [28]	validation_0-rmse:0.37762	validation_1-rmse:0.38231
# [29]	validation_0-rmse:0.37549	validation_1-rmse:0.38013
# [30]	validation_0-rmse:0.37494	validation_1-rmse:0.37969
# [31]	validation_0-rmse:0.37436	validation_1-rmse:0.37911
# [32]	validation_0-rmse:0.37224	validation_1-rmse:0.37702
# [33]	validation_0-rmse:0.37073	validation_1-rmse:0.37555
# [34]	validation_0-rmse:0.36947	validation_1-rmse:0.37439
# [35]	validation_0-rmse:0.36844	validation_1-rmse:0.37345
# [36]	validation_0-rmse:0.36693	validation_1-rmse:0.37196
# [37]	validation_0-rmse:0.36576	validation_1-rmse:0.37085
# [38]	validation_0-rmse:0.36496	validation_1-rmse:0.37010
# [39]	validation_0-rmse:0.36432	validation_1-rmse:0.36963
# [40]	validation_0-rmse:0.36371	validation_1-rmse:0.36918
# [41]	validation_0-rmse:0.36307	validation_1-rmse:0.36860
# [42]	validation_0-rmse:0.36253	validation_1-rmse:0.36821
# [43]	validation_0-rmse:0.36078	validation_1-rmse:0.36654
# [44]	validation_0-rmse:0.35951	validation_1-rmse:0.36538
# [45]	validation_0-rmse:0.35893	validation_1-rmse:0.36482
# [46]	validation_0-rmse:0.35869	validation_1-rmse:0.36468
# [47]	validation_0-rmse:0.35815	validation_1-rmse:0.36422
# [48]	validation_0-rmse:0.35721	validation_1-rmse:0.36341
# [49]	validation_0-rmse:0.35675	validation_1-rmse:0.36302
# [50]	validation_0-rmse:0.35585	validation_1-rmse:0.36214
# [51]	validation_0-rmse:0.35562	validation_1-rmse:0.36202
# [52]	validation_0-rmse:0.35495	validation_1-rmse:0.36139
# [53]	validation_0-rmse:0.35430	validation_1-rmse:0.36087
# [54]	validation_0-rmse:0.35370	validation_1-rmse:0.36036
# [55]	validation_0-rmse:0.35284	validation_1-rmse:0.35959
# [56]	validation_0-rmse:0.35246	validation_1-rmse:0.35932
# [57]	validation_0-rmse:0.35196	validation_1-rmse:0.35888
# [58]	validation_0-rmse:0.35120	validation_1-rmse:0.35821
# [59]	validation_0-rmse:0.35083	validation_1-rmse:0.35790
# [60]	validation_0-rmse:0.35058	validation_1-rmse:0.35773
# [61]	validation_0-rmse:0.34985	validation_1-rmse:0.35706
# [62]	validation_0-rmse:0.34902	validation_1-rmse:0.35630
# [63]	validation_0-rmse:0.34842	validation_1-rmse:0.35574
# [64]	validation_0-rmse:0.34798	validation_1-rmse:0.35537
# [65]	validation_0-rmse:0.34738	validation_1-rmse:0.35494
# [66]	validation_0-rmse:0.34670	validation_1-rmse:0.35435
# [67]	validation_0-rmse:0.34630	validation_1-rmse:0.35399
# [68]	validation_0-rmse:0.34569	validation_1-rmse:0.35343
# [69]	validation_0-rmse:0.34541	validation_1-rmse:0.35318
# [70]	validation_0-rmse:0.34516	validation_1-rmse:0.35304
# [71]	validation_0-rmse:0.34433	validation_1-rmse:0.35230
# [72]	validation_0-rmse:0.34337	validation_1-rmse:0.35142
# [73]	validation_0-rmse:0.34288	validation_1-rmse:0.35102
# [74]	validation_0-rmse:0.34194	validation_1-rmse:0.35009
# [75]	validation_0-rmse:0.34157	validation_1-rmse:0.34978
# [76]	validation_0-rmse:0.34049	validation_1-rmse:0.34874
# [77]	validation_0-rmse:0.33981	validation_1-rmse:0.34809
# [78]	validation_0-rmse:0.33946	validation_1-rmse:0.34778
# [79]	validation_0-rmse:0.33926	validation_1-rmse:0.34770
# [80]	validation_0-rmse:0.33899	validation_1-rmse:0.34751
# [81]	validation_0-rmse:0.33844	validation_1-rmse:0.34700
# [82]	validation_0-rmse:0.33739	validation_1-rmse:0.34601
# [83]	validation_0-rmse:0.33687	validation_1-rmse:0.34551
# [84]	validation_0-rmse:0.33629	validation_1-rmse:0.34494
# [85]	validation_0-rmse:0.33598	validation_1-rmse:0.34469
# [86]	validation_0-rmse:0.33552	validation_1-rmse:0.34430
# [87]	validation_0-rmse:0.33511	validation_1-rmse:0.34398
# [88]	validation_0-rmse:0.33457	validation_1-rmse:0.34355
# [89]	validation_0-rmse:0.33397	validation_1-rmse:0.34294
# [90]	validation_0-rmse:0.33354	validation_1-rmse:0.34252
# [91]	validation_0-rmse:0.33293	validation_1-rmse:0.34195
# [92]	validation_0-rmse:0.33243	validation_1-rmse:0.34143
# [93]	validation_0-rmse:0.33167	validation_1-rmse:0.34076
# [94]	validation_0-rmse:0.33135	validation_1-rmse:0.34047
# [95]	validation_0-rmse:0.33102	validation_1-rmse:0.34018
# [96]	validation_0-rmse:0.33091	validation_1-rmse:0.34012
# [97]	validation_0-rmse:0.33049	validation_1-rmse:0.33975
# [98]	validation_0-rmse:0.32984	validation_1-rmse:0.33917
# [99]	validation_0-rmse:0.32939	validation_1-rmse:0.33876
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# save model
joblib.dump(model4, "xgboost.joblib")
# Out:
# ['xgboost.joblib']

# %%
results4 = model4.evals_result()
results4
# Out:
# {'validation_0': OrderedDict([('rmse',
#                [0.7991815227234733,
#                 0.6678096892362847,
#                 0.583435665255147,
#                 0.5287457106504795,
#                 0.49369784553581036,
#                 0.46940714510511555,
#                 0.4541161967555122,
#                 0.4425896681029218,
#                 0.43250971350504946,
#                 0.425510916302484,
#                 0.41816511057195316,
#                 0.4113452436148603,
#                 0.40750557580899743,
#                 0.4036223717370852,
#                 0.40042862360407405,
#                 0.3981890550180266,
#                 0.3940623039135842,
#                 0.3923757373175482,
#                 0.3903653681060788,
#                 0.38792399471827377,
#                 0.3866757455874913,
#                 0.3856018739521312,
#                 0.38343702213434566,
#                 0.3814666254368087,
#                 0.38067320068515925,
#                 0.3799344148950472,
#                 0.3788164499322819,
#                 0.3781320166268105,
#                 0.3776202763060936,
#                 0.3754873927594375,
#                 0.3749432572587981,
#                 0.3743554674329987,
#                 0.3722410497483212,
#                 0.37073164797770175,
#                 0.3694680182786168,
#                 0.36844255599987186,
#                 0.36693045504608346,
#                 0.36576412977605977,
#                 0.3649645719742038,
#                 0.36432476235638767,
#                 0.36370889539021545,
#                 0.3630662009485016,
#                 0.3625317607605178,
#                 0.36078423987254205,
#                 0.35950560866950987,
#                 0.35892584343842826,
#                 0.35869427032748746,
#                 0.3581543947690964,
#                 0.35720836740201306,
#                 0.3567482514390941,
#                 0.3558517793721085,
#                 0.3556172848907311,
#                 0.35495007059903977,
#                 0.3543022027391645,
#                 0.3536960219527798,
#                 0.3528397190196973,
#                 0.35246085123158083,
#                 0.35195919666528297,
#                 0.3512037899144535,
#                 0.35083028216735546,
#                 0.3505782395979023,
#                 0.3498469684110854,
#                 0.34901654122386844,
#                 0.34841576717281547,
#                 0.3479840622486559,
#                 0.34738339101683297,
#                 0.34669677790650716,
#                 0.3462962676397959,
#                 0.34568750272248144,
#                 0.3454135091868475,
#                 0.3451569814637651,
#                 0.3443326006820759,
#                 0.3433730816646136,
#                 0.342882394231249,
#                 0.34193626117643117,
#                 0.3415730321765905,
#                 0.3404907993238,
#                 0.3398149282135688,
#                 0.3394573089667322,
#                 0.33925942967988243,
#                 0.3389901704529644,
#                 0.33843730556617146,
#                 0.3373885621225297,
#                 0.33687133244891904,
#                 0.336288012201748,
#                 0.33597684415279644,
#                 0.3355157703820269,
#                 0.3351099646515565,
#                 0.334573441347228,
#                 0.333973711569833,
#                 0.33353901932943464,
#                 0.3329299840878479,
#                 0.332432784201591,
#                 0.3316665837631348,
#                 0.3313519833164449,
#                 0.3310244349409678,
#                 0.3309123448048992,
#                 0.330489640972991,
#                 0.3298439211170382,
#                 0.32938796955776156])]),
#  'validation_1': OrderedDict([('rmse',
#                [0.8000621017274078,
#                 0.6689091570576333,
#                 0.5850825644726199,
#                 0.5310185754282039,
#                 0.49617543852850304,
#                 0.47226096417169616,
#                 0.45711158169080895,
#                 0.4456149250320249,
#                 0.43553556031247104,
#                 0.42866427007077196,
#                 0.42135791824554575,
#                 0.41478592444840007,
#                 0.4111094280081363,
#                 0.40716049199678644,
#                 0.40410976778074836,
#                 0.40191529192582093,
#                 0.39778737859636054,
#                 0.3960947883604929,
#                 0.3941259322848938,
#                 0.3917141594224887,
#                 0.39051654886097426,
#                 0.38950978581116585,
#                 0.38744098732699966,
#                 0.3856330713323571,
#                 0.38491060035558017,
#                 0.3842896213794009,
#                 0.38328703775455736,
#                 0.38272376321655455,
#                 0.3823121626801552,
#                 0.3801297068685572,
#                 0.37969119279821983,
#                 0.3791142964840268,
#                 0.37702207849274333,
#                 0.3755498608052798,
#                 0.3743931600693011,
#                 0.3734472509931237,
#                 0.37196304409030717,
#                 0.37084986265082254,
#                 0.3700991735847578,
#                 0.36962931505610364,
#                 0.3691768193762717,
#                 0.3686020763633395,
#                 0.3682090954478954,
#                 0.36653725271591986,
#                 0.36537708232611676,
#                 0.36482189927796305,
#                 0.36467831054285077,
#                 0.36422193867633623,
#                 0.3634135570501279,
#                 0.3630174290217734,
#                 0.3621403656410164,
#                 0.3620239709521227,
#                 0.3613902055848914,
#                 0.3608731624630899,
#                 0.36035583197543636,
#                 0.3595851194813969,
#                 0.35932471661865756,
#                 0.35888373026825776,
#                 0.3582065788996096,
#                 0.3579030585105725,
#                 0.3577298850754298,
#                 0.35705804877969843,
#                 0.3563023016785577,
#                 0.35573977921112143,
#                 0.3553710626943404,
#                 0.3549378006825657,
#                 0.3543533112897723,
#                 0.3539898803763371,
#                 0.35342680653208663,
#                 0.3531837646940841,
#                 0.3530354818706174,
#                 0.3522967305747243,
#                 0.35141766684033665,
#                 0.35101875054837123,
#                 0.3500908508494581,
#                 0.34978350288600457,
#                 0.3487443537225366,
#                 0.3480943929241797,
#                 0.3477847173013997,
#                 0.3476993041454853,
#                 0.34751225516532036,
#                 0.34700206889186486,
#                 0.3460072094334971,
#                 0.3455057078516179,
#                 0.34494275409631003,
#                 0.344689244948887,
#                 0.34430222440980257,
#                 0.34398390796061507,
#                 0.3435457842967823,
#                 0.3429424655345066,
#                 0.3425169069095017,
#                 0.34194825527044653,
#                 0.3414316990618833,
#                 0.3407595163279441,
#                 0.34047096283845224,
#                 0.34018227949850843,
#                 0.34011835842998756,
#                 0.3397531386518711,
#                 0.33916949599395907,
#                 0.3387566766600664])])}

# %%
model4.score(x_test_normalized, y_test_normalized.T[0])
# Out:
# 0.8852803945652781

# %%
# Get the metrics on the validation data
predicted_availability4 = model4.predict(x_test_normalized)

# %%
mae4 = mean_absolute_error(y_test_normalized.T[0], predicted_availability4)
print('XGBoost test MAE = ', mae4)
# Out:
# XGBoost test MAE =  tf.Tensor(0.18574291, shape=(), dtype=float32)

# %%
mse4 = mean_squared_error(y_test_normalized.T[0], predicted_availability4)
rmse4 = mse4**.5
print('XGBoost test MSE = ', mse4)
print('XGBoost test RMSE = ', rmse4)
# Out:
# XGBoost test MSE =  tf.Tensor(0.1147561, shape=(), dtype=float32)
# XGBoost test RMSE =  tf.Tensor(0.3387567, shape=(), dtype=float32)

# %%
epochs = len(results4['validation_0']['rmse'])
x_axis = range(0, epochs)

fig, ax = plt.subplots()

ax.plot(x_axis, results4['validation_0']['rmse'], label='Train')
ax.plot(x_axis, results4['validation_1']['rmse'], label='Test')

plt.title('XGBoost RMSE')
plt.xlabel("Boosting Iterations")
plt.ylabel("RMSE Deviance")
plt.legend(loc="upper right");

# %%
xgb.plot_importance(model4);

# %%
result4 = permutation_importance(
    model4, x_test_normalized, y_test_normalized.T[0], n_repeats=10, random_state=42, n_jobs=2
)

# %%
tree_importances4 = pd.Series(result4.importances_mean, index=feature_names)

# %%
# sort features according to importance
sorted_idx = np.argsort(tree_importances4)
pos = np.arange(sorted_idx.shape[0])

# plot feature importances
plt.barh(pos, tree_importances4[sorted_idx], align="center")

plt.yticks(pos, np.array(feature_names)[sorted_idx])
plt.title("Feature Importance (MDI)")
plt.xlabel("Mean decrease in impurity");

# %%
plt.boxplot(
    result4.importances[sorted_idx].T,
    vert=False,
    labels=np.array(feature_names)[sorted_idx],
)

plt.title("Permutation Importance (test set)")
plt.show()

# %%
model6 = VotingRegressor([("linear", model1), ("random-forest", model2), ("hist-grad-boost-reg", model3), ("xgb", model4)]) 
model6.fit(x_train_normalized, y_train_normalized.T[0])
# Out:
# VotingRegressor(estimators=[('linear', LinearRegression()),
#                             ('random-forest', RandomForestRegressor()),
#                             ('hist-grad-boost-reg',
#                              HistGradientBoostingRegressor()),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False...
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           random_state=None, ...))])

# %%
# save model
joblib.dump(model6, "voting.joblib")
# Out:
# ['voting.joblib']

# %%
model6.score(x_test_normalized, y_test_normalized.T[0])
# Out:
# 0.8689085698979754

# %%
predicted_availability6 = model6.predict(x_test_normalized)

# %%
mae6 = mean_absolute_error(y_test_normalized.T[0], predicted_availability6)
print('Voting test MAE = ', mae6)
# Out:
# Voting test MAE =  tf.Tensor(0.22670907542100166, shape=(), dtype=float64)

# %%
mse6 = mean_squared_error(y_test_normalized.T[0], predicted_availability6)
rmse6 = mse6**.5
print('Voting test MSE = ', mse6)
print('Voting test RMSE = ', rmse6)
# Out:
# Voting test MSE =  tf.Tensor(0.1311331162509589, shape=(), dtype=float64)
# Voting test RMSE =  tf.Tensor(0.3621230678249577, shape=(), dtype=float64)

# %%
plt.figure()
plt.plot(predicted_availability1, "ys", label="LinearRegression")
plt.plot(predicted_availability2, "b^", label="RandomForestRegressor")
plt.plot(predicted_availability3, "gd", label="HistGradientBoostingRegressor")
plt.plot(predicted_availability4, "pc", ms=10, label="XGBoost")
plt.plot(predicted_availability6, "r*", ms=10, label="VotingRegressor")

plt.tick_params(axis="x", which="both", bottom=False, top=False, labelbottom=False)
plt.ylabel("predicted")
plt.xlabel("training samples")
plt.legend(loc="best")
plt.title("Regressor predictions and their average")

plt.show()
